# %%
import json
import openai
import os
import random
from dotenv import load_dotenv as dotenv_load_dotenv

# Define function to load environment variables from .env file
def load_dotenv_file():
    # load environment variables from .env file
    dotenv_load_dotenv('.secrets.env')

def load_env_vars():
    load_dotenv_file()
    # set API key from environment variable
    openai.api_key = os.getenv("OPENAI_API_KEY")

# load environment variables from .env file
load_env_vars()

# Load arcsDicts.json

def load_json():
    with open('arcsDicts.json') as f:
        data = json.load(f)
    return data

# Call the function to get the selected arc and its phases
data = load_json()
random_arc_data = random.choice(data)
random_arc = random_arc_data["arc"]
phases = list(random_arc_data["phases"].values())

print("Selected arc:")
print(random_arc)

# Path: apiFunctions.py
parameters = {
    "model": "text-davinci-003",
    "prompt": "List classic story arcs in fiction.",
    "temperature": 0,  # 0 means no randomness 1 means completely random
    "max_tokens": 50,  # max number of tokens to generate
    "top_p": 1,  # 1 means no filtering, 0 means only the most likely token`
    # 0 means no penalty, 1 means penalize new tokens based on their existing frequency
    "frequency_penalty": 1,
    # 0 means no penalty, 1 means penalize new tokens based on whether they appear in the prompt
    "presence_penalty": 1
}

# Create a variable to store the chat history
chat_history = []

# Define a function to generate a response to a prompt
def chat_request_response(prompt):
    # Example OpenAI Python library request
    MODEL = "text-davinci-002"
    response = openai.Completion.create(
        engine=MODEL,
        prompt=prompt,
        temperature=0.9,
        max_tokens=1000,
        n=1,
        stop=None,
        frequency_penalty=0,
        presence_penalty=0,
    )
    # Get the message object from the first choice
    message = response["choices"][0]["text"].strip()
    return message

# Call the function to start the chat
first_prompt = f"Write the introduction to a novel in the {random_arc} arc style."
response = chat_request_response(first_prompt)
print(response)
chat_history.append(response)

# Call the function to generate subsequent responses
for phase in phases:
    prompt = f"Write a paragraph in the '{phase}' phase of the {random_arc} arc style."
    response = chat_request_response(prompt)
    print(response)
    chat_history.append(response)

print(random_arc)
print(chat_history)
# Out:
# Selected arc:
# The Quest
# When the kingdom of Alderaan is invaded by the evil empire, the king and queen are forced to flee their home. They take their infant daughter, Princess Leia, with them, but are captured by imperial forces. The king is killed and the queen is taken prisoner.
#
# Leia is hidden on the planet Tatooine, where she is raised by the Lars family. When she is 19 years old, Leia joins the rebel alliance and helps lead the fight against the empire. After the death of her mother, Leia becomes the new queen of Alderaan.
#
# The Quest arc style is a style of writing that is similar to a fairy tale. It is characterized by adventure, magic, and heroic characters.
# The call to action comes in the form of a cryptic message from an unknown sender. It tells the hero that they are the chosen one and only they can save the world from an impending doom. They must embark on a journey to find the ancient artifacts that can stop the doom from coming. With the help of their trusty sidekick, they set out on their quest.
# The hero sets out on their journey, often leaving their home or comfort zone behind. They may have a specific goal in mind, or they may be simply searching for something new. Either way, they will face many challenges along the way. These challenges will test their resolve and strength of character. Ultimately, the hero will prevail and return home a changed person.
# The hero encounters a series of trials and challenges, which test their skills and character. The hero must overcome these challenges to complete their quest.
# At this point in the story, the hero has realized that they cannot complete their quest alone and begin to seek out others who can help them. This may involve recruiting allies from among their friends and acquaintances or, in some cases, strangers who are specialist in the areas that the hero needs help in. In any case, the goal is to gather a team of companions who can assist the hero in overcoming the challenges ahead.
# As the sun began to set, the hero knew that time was running out. He had to find the lost city of Goldendale before the nightfall. With only a map and his trusty sword, he set out into the unknown.
# As the darkness closed in around her, she knew this was the end. She had fought so hard and for so long, but it was time to give up. She was exhausted, battered, and broken. She lay down in the snow, ready to die. But then she saw the light. It was her son, come to save her. With his help, she got up and fought on. She knew she had to for him. And she defeated the darkness, emerging victorious. She was transformed by the experience, and her love for her son.
# The hero's journey is not complete until they receive their reward or knowledge. This can come in many forms, but it is always a result of their hard work and trials. The reward may be something they have been seeking all along, or it may be something they never even knew they wanted. Either way, it is always a valuable prize. Knowledge is also a common reward, and it is often more valuable than any material object. This knowledge can be used to help the hero in their future quests, and it is always a valuable asset.
# The hero begins their journey back to their home or community. They are changed by their adventure and must now face the challenges that await them. They must use their new found knowledge and courage to overcome these challenges and make their home or community a better place.
# The hero's final challenge is a test of their strength, courage, and resolve. They must face their fears and overcome them to succeed. This may be a physical challenge, such as a battle, or a mental one, such as a puzzle or riddle. The hero must use all their skills and knowledge to prevail.
# Though the hero may have changed during their journey, their home or community remains the same. The hero returns with a valuable treasure or gift that will benefit others, often using it to restore balance to their community. The hero may also take on a leadership role in their community, using their new knowledge and experience to help others.
# The Quest
# ['When the kingdom of Alderaan is invaded by the evil empire, the king and queen are forced to flee their home. They take their infant daughter, Princess Leia, with them, but are captured by imperial forces. The king is killed and the queen is taken prisoner.\n\nLeia is hidden on the planet Tatooine, where she is raised by the Lars family. When she is 19 years old, Leia joins the rebel alliance and helps lead the fight against the empire. After the death of her mother, Leia becomes the new queen of Alderaan.\n\nThe Quest arc style is a style of writing that is similar to a fairy tale. It is characterized by adventure, magic, and heroic characters.', 'The call to action comes in the form of a cryptic message from an unknown sender. It tells the hero that they are the chosen one and only they can save the world from an impending doom. They must embark on a journey to find the ancient artifacts that can stop the doom from coming. With the help of their trusty sidekick, they set out on their quest.', 'The hero sets out on their journey, often leaving their home or comfort zone behind. They may have a specific goal in mind, or they may be simply searching for something new. Either way, they will face many challenges along the way. These challenges will test their resolve and strength of character. Ultimately, the hero will prevail and return home a changed person.', 'The hero encounters a series of trials and challenges, which test their skills and character. The hero must overcome these challenges to complete their quest.', 'At this point in the story, the hero has realized that they cannot complete their quest alone and begin to seek out others who can help them. This may involve recruiting allies from among their friends and acquaintances or, in some cases, strangers who are specialist in the areas that the hero needs help in. In any case, the goal is to gather a team of companions who can assist the hero in overcoming the challenges ahead.', 'As the sun began to set, the hero knew that time was running out. He had to find the lost city of Goldendale before the nightfall. With only a map and his trusty sword, he set out into the unknown.', 'As the darkness closed in around her, she knew this was the end. She had fought so hard and for so long, but it was time to give up. She was exhausted, battered, and broken. She lay down in the snow, ready to die. But then she saw the light. It was her son, come to save her. With his help, she got up and fought on. She knew she had to for him. And she defeated the darkness, emerging victorious. She was transformed by the experience, and her love for her son.', "The hero's journey is not complete until they receive their reward or knowledge. This can come in many forms, but it is always a result of their hard work and trials. The reward may be something they have been seeking all along, or it may be something they never even knew they wanted. Either way, it is always a valuable prize. Knowledge is also a common reward, and it is often more valuable than any material object. This knowledge can be used to help the hero in their future quests, and it is always a valuable asset.", 'The hero begins their journey back to their home or community. They are changed by their adventure and must now face the challenges that await them. They must use their new found knowledge and courage to overcome these challenges and make their home or community a better place.', "The hero's final challenge is a test of their strength, courage, and resolve. They must face their fears and overcome them to succeed. This may be a physical challenge, such as a battle, or a mental one, such as a puzzle or riddle. The hero must use all their skills and knowledge to prevail.", 'Though the hero may have changed during their journey, their home or community remains the same. The hero returns with a valuable treasure or gift that will benefit others, often using it to restore balance to their community. The hero may also take on  ...
