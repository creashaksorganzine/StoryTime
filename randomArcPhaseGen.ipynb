# %%
import json
import openai
import os
import random
from dotenv import load_dotenv as dotenv_load_dotenv

def load_dotenv_file():
    dotenv_load_dotenv('.secrets.env')

def load_env_vars():
    load_dotenv_file()
    openai.api_key = os.getenv("OPENAI_API_KEY")

def load_json():
    with open('arcsDicts.json') as f:
        data = json.load(f)
    return data

def select_story_arc():
    data = load_json()
    random_arc_data = random.choice(data)
    random_arc = random_arc_data["arc"]
    phases = list(random_arc_data["phases"].values())
    return random_arc, phases

def chat_request_response(prompt):
    MODEL = "text-davinci-003"
    response = openai.Completion.create(
        engine=MODEL,
        prompt=prompt,
        temperature=0.9,
        max_tokens=1000,
        n=1,
        stop=None,
        frequency_penalty=0,
        presence_penalty=0,
    )
    message = response["choices"][0]["text"].strip()
    return message

def extract_story_elements(text):
    # Implement a custom function to extract story elements like characters, places, etc.
    # This is just a simple example; you can improve the function based on your requirements.
    story_elements = {
        "characters": [],
        "places": []
    }
    # Add your extraction logic here
    return story_elements

def return_json(random_arc, phases, chat_history):
    return {'story_arc': random_arc, 'phases': phases, 'chat_history': chat_history}

load_env_vars()
chat_history = []

random_arc, phases = select_story_arc()

first_prompt = f"Write the introduction to a novel in the {random_arc} arc style."
response = chat_request_response(first_prompt)
story_elements = extract_story_elements(response)
chat_history.append({'phase': 'introduction', 'text': response, 'story_elements': story_elements})

for phase in phases:
    prompt = f"Write a paragraph in the '{phase}' phase of the {random_arc} arc style."
    response = chat_request_response(prompt)
    story_elements = extract_story_elements(response)
    chat_history.append({'phase': phase, 'text': response, 'story_elements': story_elements})

response_data = return_json(random_arc, phases, chat_history)

with open('output.json', 'w') as outfile:
    json.dump(response_data, outfile, indent=4)

# %%
def extract_story_elements(text):
    # Extract keywords from the text using OpenAI API
    MODEL = "text-davinci-003"
    response = openai.Completion.create(
        engine=MODEL,
        prompt=f"Extract keywords from this text:\n\n{text}\n\nKeywords:",
        temperature=0.5,
        max_tokens=60,
        n=1,
        stop=None,
        frequency_penalty=0.8,
        presence_penalty=0
    )
    keywords = response["choices"][0]["text"].strip().split(", ")
    
    # Implement a custom function to extract other story elements like characters, places, etc.
    # This is just a simple example; you can improve the function based on your requirements.
    story_elements = {
        "characters": [],
        "places": [],
        "keywords": keywords
    }
    # Add your extraction logic here
    return story_elements

# %%
# for phase in phases:
#     prompt = f"Write a paragraph in the '{phase}' phase of the {random_arc} arc style."
#     response = chat_request_response(prompt)
#     story_elements = extract_story_elements(response)
#     chat_history.append({'phase': phase, 'text': response, 'story_elements': story_elements})

# print(chat_history)
# Out:
# [{'phase': 'introduction', 'text': 'The darkness had been slowly encroaching on their small, peaceful village for weeks, ever since the first sightings of the mysterious monster. No one knew where it came from, or why it had decided to make the village its home. Fear and dread spread through the villagers like a plague, and all that remained was waiting for the inevitable.\n\nBut on one fateful night, a fearless young hero stood up to the beast. Armed with nothing but their courage and determination, the hero set out to slay the monster and free the village from its terror. What obstacles and perils would they face? Could they succeed in this seemingly impossible task, or would the monster triumph in the end?', 'story_elements': {'characters': [], 'places': []}}, {'phase': 'The hero learns about a menacing monster or villain that threatens the community.', 'text': 'The hero learns that a menacing monster is threatening their community. This monster is said to be a relentless force of evil, destroying all in its path with unimaginable power and ferocity. People tell stories of inhuman cries coming from deep within the forest at night, and how this powerful creature can bring ruin and death to anyone who stands in its way. The hero sets out to discover the truth and save their beloved home, but they have no idea of the trials that await them and the darkness that lies ahead.', 'story_elements': {'characters': [], 'places': []}}, {'phase': 'The hero is called upon to defeat the monster and save the community.', 'text': 'The hero was tasked with a daunting mission - to defeat the monster and protect the community. With no other choice, the hero stepped forward and courageously accepted the challenge. He was determined to fight for the safety of his people, no matter the consequences. He suited up and armed with strength, courage, and determination, the hero set out to face the monster. He was prepared for whatever lay ahead and was determined to come out victorious and save the community from the terror the monster had caused.', 'story_elements': {'characters': [], 'places': []}}, {'phase': 'The hero gathers allies and resources to aid them in their quest to defeat the monster.', 'text': "The hero was determined to overcome the monster, and so they set out to rally allies and resources to their cause. They began by reaching out to lifelong friends and acquaintances, hoping they would be willing to aid in the fight against the monster. After much convincing, their allies eventually agreed to join them in their quest, providing the hero with a range of skills and tools that would prove invaluable against the beast. Next, the hero sought out resources, such as magical artifacts and weapons, that could be used in the battle. With a little bit of luck, the hero was able to acquire a powerful magical artifact that would give them an edge against the monster. Finally, the hero's preparations were complete, and they were now ready to take on the monster.", 'story_elements': {'characters': [], 'places': []}}, {'phase': "The hero sets out on a journey to the monster's lair, facing obstacles and challenges along the way.", 'text': 'The hero set out on a daunting journey to the monster’s lair. Although the hero was afraid and unsure if he could prevail, he had taken it upon himself to take on this challenge. As the hero moved closer to the monster’s lair, he encountered many obstacles and challenges. He had to brave treacherous terrain and battle enemies that lurked around every corner. On top of that, the hero was afflicted with feelings of fear and doubt which made his journey even harder. However, the hero carried on, determined to complete his mission.', 'story_elements': {'characters': [], 'places': []}}, {'phase': 'The hero confronts the monster in a final battle, using their skills and resources to overcome it.', 'text': "The hero and monster collided in a thunderous clash of steel and fury. The hero used their strength and skill, coup ...
# Bad pipe message: %s [b'?\xdd\xc9\xeb\x92Q29\x96\xaf\xfb\xd4\x05\x8bI\x9b\x88\xd8 ,\xb5\xec=\xa81v\x17\xe0\xf1\x89\xec\xb0;R\xa87\x98N\x17p\x17\xf6\xdb=\xa4\xf6\x88$[\xcf\xdd\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x02N1\xe9\xff,B\x88\x96i\xa9\xf0\xf4\xc6']
# Bad pipe message: %s [b'\xb8GNm\xbbQ\x04"\xa34\xb7\xc41J\xbfV\xd3\x9c\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0\'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03']
# Bad pipe message: %s [b'\x06\x03\x08\x07', b'\x08\t\x08\n\x08\x0b\x08']
# Bad pipe message: %s [b'\x05\x08\x06']
# Bad pipe message: %s [b"\xaf\xdfq K\xfc-\xf8@\xbd\x9e1\xef\xaf5\xc2\xc00\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00"]
# Bad pipe message: %s [b'\x05\x01\x06', b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'\x87s\x9dx\xe8\x14\xaf<\xf58\xb5x\r\xd2']
# Bad pipe message: %s [b'\xaf\x13\x8b\xc7\xd03&\x00kk\xe7\xf0\x1a\xc8\xd97#\xdc\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00']
# Bad pipe message: %s [b'\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01']
# Bad pipe message: %s [b'', b'\x00\x02']
# Bad pipe message: %s [b"\xcc,\xec\xc76\x87\xef\xe565g\x97('\xfe\x80\x81\xeb\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00", b'\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03']
# Bad pipe message: %s [b'\x16\xdb\xa9\x18\xdd^\x1e\x1d\xb1+\x95\xcd_b\x81\xdfm\xd0\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D']
# Bad pipe message: %s [b'\x9b-\x0e`\xffa\xf5\x9e\x98\x8c\xdb\xd4\xf3+>D\x02R\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0', b'\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009']
# Bad pipe message: %s [b"\xa5\x0f\xc9gy\x81\x19\xc6i>\xfadR\x9e\xf3\x8d\xf8\xe3\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11"]

# %%
# import os
# import openai
# from dotenv import load_dotenv as dotenv_load_dotenv
# import json

# def load_dotenv_file():
#     dotenv_load_dotenv('.secrets.env')

# def load_env_vars():
#     load_dotenv_file()
#     openai.api_key = os.getenv("OPENAI_API_KEY")

# load_env_vars()

# openai.api_key = os.getenv("OPENAI_API_KEY")
# openai.Model.list()

# with open('model.json', 'w') as outfile:
#     json.dump(openai.Model.list(), outfile, indent=4)

# %%
# import json
# import openai
# import os
# from dotenv import load_dotenv as dotenv_load_dotenv

# def load_dotenv_file():
#     dotenv_load_dotenv('.secrets.env')

# def load_env_vars():
#     load_dotenv_file()
#     openai.api_key = os.getenv("OPENAI_API_KEY")

# def analyze_text(text):
#     # Call OpenAI API to analyze the text and extract story elements
#     # You can customize this function based on your specific requirements
#     MODEL = "text-davinci-001"
#     prompt = f"Extract story elements like characters and places from the following text:\n\n{text}"
    
#     response = openai.Completion.create(
#         engine=MODEL,
#         prompt=prompt,
#         temperature=0.1,
#         max_tokens=100,
#         n=1,
#         stop=None,
#         frequency_penalty=0,
#         presence_penalty=0,
#     )
    
#     analyzed_text = response["choices"][0]["text"].strip()
#     return analyzed_text

# def update_story_elements(chat_history):
#     for entry in chat_history:
#         phase_text = entry["text"]
#         story_elements = analyze_text(phase_text)
#         entry["story_elements"] = story_elements
#     return chat_history

# load_env_vars()

# # Read output.json
# with open('output.json', 'r') as infile:
#     data = json.load(infile)

# chat_history = data["chat_history"]

# # Update the chat history with analyzed story elements
# chat_history_updated = update_story_elements(chat_history)

# # Save the updated chat history to output_analyzed.json
# data["chat_history"] = chat_history_updated
# with open('output_analyzed.json', 'w') as outfile:
#     json.dump(data, outfile, indent=4)
